# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AndhraP_Health_Insurance_Data.csv',parse_dates=["PREAUTH_DATE", "CLAIM_DATE", "SURGERY_DATE", "DISCHARGE_DATE"])
df.head()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_996\3153962856.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.read_csv('AndhraP_Health_Insurance_Data.csv',parse_dates=["PREAUTH_DATE", "CLAIM_DATE", "SURGERY_DATE", "DISCHARGE_DATE"])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_996\3153962856.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.read_csv('AndhraP_Health_Insurance_Data.csv',parse_dates=["PREAUTH_DATE", "CLAIM_DATE", "SURGERY_DATE", "DISCHARGE_DATE"])
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479688 entries, 0 to 479687
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sno               479688 non-null  int64
#  1   AGE               479688 non-null  int64
#  2   SEX               479688 non-null  object
#  3   CASTE_NAME        479688 non-null  object
#  4   CATEGORY_CODE     479688 non-null  object
#  5   CATEGORY_NAME     479688 non-null  object
#  6   SURGERY_CODE      479688 non-null  object
#  7   SURGERY           479688 non-null  object
#  8   VILLAGE           479688 non-null  object
#  9   MANDAL_NAME       479688 non-null  object
#  10  DISTRICT_NAME     479688 non-null  object
#  11  PREAUTH_DATE      479688 non-null  datetime64[ns]
#  12  PREAUTH_AMT       479688 non-null  int64
#  13  CLAIM_DATE        479688 non-null  datetime64[ns]
#  14  CLAIM_AMOUNT      479688 non-null  int64
# ...

# %%
df.shape
# Out:
# (479688, 22)

# %%
df.isnull().mean()*100
# Out:
# Sno                 0.0
# AGE                 0.0
# SEX                 0.0
# CASTE_NAME          0.0
# CATEGORY_CODE       0.0
# CATEGORY_NAME       0.0
# SURGERY_CODE        0.0
# SURGERY             0.0
# VILLAGE             0.0
# MANDAL_NAME         0.0
# DISTRICT_NAME       0.0
# PREAUTH_DATE        0.0
# PREAUTH_AMT         0.0
# CLAIM_DATE          0.0
# CLAIM_AMOUNT        0.0
# HOSP_NAME           0.0
# HOSP_TYPE           0.0
# HOSP_DISTRICT       0.0
# SURGERY_DATE        0.0
# DISCHARGE_DATE      0.0
# Mortality Y / N     0.0
# SRC_REGISTRATION    0.0
# dtype: float64

# %%
print(df.isnull().sum())
# Out:
# Sno                 0
# AGE                 0
# SEX                 0
# CASTE_NAME          0
# CATEGORY_CODE       0
# CATEGORY_NAME       0
# SURGERY_CODE        0
# SURGERY             0
# VILLAGE             0
# MANDAL_NAME         0
# DISTRICT_NAME       0
# PREAUTH_DATE        0
# PREAUTH_AMT         0
# CLAIM_DATE          0
# CLAIM_AMOUNT        0
# HOSP_NAME           0
# HOSP_TYPE           0
# HOSP_DISTRICT       0
# SURGERY_DATE        0
# DISCHARGE_DATE      0
# Mortality Y / N     0
# SRC_REGISTRATION    0
# dtype: int64

# %%
# nuerical data 
# 1. box plot
# 2. histogram
# 3. distplot

# categorical 
# 1. count plot
# 2. piechart

# %% [markdown]
# # Numerical data

# %%
# 1. BOX PLOT

# %%
df.describe()
# Out:
#                Sno            AGE    PREAUTH_AMT   CLAIM_AMOUNT
# count  479688.0000  479688.000000  479688.000000  479688.000000
# mean   239844.5000      44.912264   30428.941698   27652.205861
# std    138474.1423      18.961084   27441.592281   25951.706037
# min         1.0000       0.000000       5.000000       2.000000
# 25%    119922.7500      34.000000   12500.000000   12500.000000
# 50%    239844.5000      47.000000   25000.000000   23200.000000
# 75%    359766.2500      59.000000   35000.000000   30600.000000
# max    479688.0000     107.000000  520000.000000  520000.000000

# %%
sns.boxplot(df['AGE'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['PREAUTH_AMT'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['CLAIM_AMOUNT'])
# Out:
# <Axes: >

# %%
# 2. histogram

# %%
sns.histplot(df['AGE'],bins=4)
# Out:
# <Axes: xlabel='AGE', ylabel='Count'>

# %%
sns.histplot(df['PREAUTH_AMT'],bins=4)
# Out:
# <Axes: xlabel='PREAUTH_AMT', ylabel='Count'>

# %%
sns.histplot(df['CLAIM_AMOUNT'],bins=4)
# Out:
# <Axes: xlabel='CLAIM_AMOUNT', ylabel='Count'>

# %%
# 3. DistPlot

# %%
sns.distplot(df['AGE'],bins=4)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_996\1712914522.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['AGE'],bins=4)
# <Axes: xlabel='AGE', ylabel='Density'>

# %%
sns.distplot(df['PREAUTH_AMT'],bins=4)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_996\546120704.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['PREAUTH_AMT'],bins=4)
# <Axes: xlabel='PREAUTH_AMT', ylabel='Density'>

# %%
sns.distplot(df['CLAIM_AMOUNT'],bins=4)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_996\2675921403.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CLAIM_AMOUNT'],bins=4)
# <Axes: xlabel='CLAIM_AMOUNT', ylabel='Density'>

# %%
df['SEX'] = df['SEX'].replace({'FEMALE': 'Female', 'MALE': 'Male'})

# %%
sns.countplot(df, x=df['SEX'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # CATEGORICAL

# %% [markdown]
# # 1. COUNT PLOT

# %%
df.head(2)
# Out:
#    Sno  AGE     SEX CASTE_NAME CATEGORY_CODE CATEGORY_NAME SURGERY_CODE  \
# 0    1   56  Female         BC            M6    NEPHROLOGY         M6.5
# 1    2   37    Male         BC            M6    NEPHROLOGY         M6.5
#
#                             SURGERY    VILLAGE MANDAL_NAME  ... PREAUTH_AMT  \
# 0  Maintenance Hemodialysis For Crf     Lolugu     Ponduru  ...       12500
# 1  Maintenance Hemodialysis For Crf  Borivanka      Kaviti  ...       12500
#
#   CLAIM_DATE  CLAIM_AMOUNT                                HOSP_NAME  \
# 0 2017-03-22         11000  Rims Govt. General Hospital, Srikakulam
# 1 2017-03-22         11000  Rims Govt. General Hospital, Srikakulam
#
#    HOSP_TYPE HOSP_DISTRICT SURGERY_DATE DISCHARGE_DATE Mortality Y / N  \
# 0          G    Srikakulam   2013-06-08     2013-07-09              NO
# 1          G    Srikakulam   2013-08-08     2013-09-09              NO
#
#   SRC_REGISTRATION
# 0                D
# 1                D
#
# [2 rows x 22 columns]

# %%
# sns.countplot(df, x=df['SEX'])

sns.countplot(df, x=df['SEX'])
plt.xticks(rotation=90)
plt.show()

# %%
gender_count = df.groupby('SEX').agg(count=('SEX', 'size'))     
print(gender_count)
# Out:
#                 count
# SEX
# Female         178968
# Female(Child)   14925
# Male           260727
# Male(Child)     25068

# %%
sns.countplot(df, x=df['CASTE_NAME'])
plt.xticks(rotation=90)
plt.show()

# %%
caste_count = df.groupby('CASTE_NAME').agg(count=('SEX', 'size'))     
print(caste_count)
# Out:
#              count
# CASTE_NAME
# BC          246164
# Minorities   29150
# OC          114123
# Others         371
# SC           76742
# ST           13138

# %%
sns.countplot(df, x=df['CATEGORY_NAME'])
plt.xticks(rotation=90)
plt.show()

# %%
CATEGORY_NAME_count = df.groupby('CATEGORY_NAME').agg(count=('SEX', 'size'))     
print(CATEGORY_NAME_count)
# Out:
#                                      count
# CATEGORY_NAME
# CARDIAC AND CARDIOTHORACIC SURGERY   44201
# CARDIOLOGY                           18629
# COCHLEAR IMPLANT SURGERY                74
# CRITICAL CARE                         2321
# DERMATOLOGY                             82
# ENDOCRINOLOGY                          510
# ENT  SURGERY                         12101
# GASTROENTEROLOGY                      3969
# GENERAL MEDICINE                      1366
# GENERAL SURGERY                      24309
# GENITO URINARY SURGERIES             40514
# GYNAECOLOGY AND OBSTETRICS  SURGERY   3719
# INFECTIOUS DISEASES                      5
# MEDICAL ONCOLOGY                     70158
# NEPHROLOGY                           74947
# NEUROLOGY                            13361
# NEUROSURGERY                         10917
# OPHTHALMOLOGY  SURGERY               14790
# ORTHOPEDIC  SURGERY AND PROCEDURES   15780
# PEDIATRIC SURGERIES                   4132
# ...

# %%
SURGERY_count = df.groupby('SURGERY').agg(count=('SURGERY', 'size'))     
print(SURGERY_count)
# Out:
#                                                     count
# SURGERY
#  Thoracostomy                                         104
# A V Fistula surgery (creation) at Wrist               896
# A. V Fistula surgery (creation) At Elbow              510
# A.V. Fistula surgery (creation) [Pre-Transplant...   2476
# ASD Device Closure                                    469
# ...                                                   ...
# Whipples Any Type  In malignant conditions            101
# Wide Excision - Breast in malignant conditions        171
# surgical management (Correction) of TAPVC              76
# surgical management of Ruptured Sinus Of Valsalva      20
# ursl                                                15499
#
# [923 rows x 1 columns]

# %%
sns.countplot(df, x=df['MANDAL_NAME'].head(5))
plt.xticks(rotation=90)
plt.show()

# %%
MANDAL_NAME_count = df.groupby('MANDAL_NAME').agg(count=('MANDAL_NAME', 'size'))     
print(MANDAL_NAME_count)
# Out:
#                 count
# MANDAL_NAME
# A Konduru         482
# Achampeta         504
# Achanta           618
# Addanki          1064
# Addteegala        276
# ...               ...
# Yerraguntla       687
# Yerravaripalem    326
# Zarugumilli       484
# burgampadu         30
# devankonda          1
#
# [711 rows x 1 columns]

# %%
sns.countplot(df, x=df['DISTRICT_NAME'])
plt.xticks(rotation=90)
plt.show()

# %%
DISTRICT_NAME_count = df.groupby('DISTRICT_NAME').agg(count=('DISTRICT_NAME', 'size'))     
print(DISTRICT_NAME_count)
# Out:
#                 count
# DISTRICT_NAME
# Anantapur       28854
# Chittoor        36790
# East Godavari   55398
# Guntur          50416
# Krishna         41964
# Kurnool         32013
# Nellore         39836
# Prakasam        34819
# Srikakulam      27079
# Vishakhapatnam  36481
# Vizianagaram    25799
# West Godavari   40995
# YSR Kadapa      29244

# %%
sns.countplot(df, x=df['HOSP_TYPE'])
plt.xticks(rotation=90)
plt.show()

# %%
HOSP_TYPE_count = df.groupby('HOSP_TYPE').agg(count=('HOSP_TYPE', 'size'))     
print(HOSP_TYPE_count)
# Out:
#             count
# HOSP_TYPE
# C          369346
# G          110342

# %%
sns.countplot(df, x=df['Mortality Y / N'])
plt.xticks(rotation=90)
plt.show()

# %%
mortality_count = df.groupby('Mortality Y / N').agg(count=('Mortality Y / N', 'size'))     
print(mortality_count)
# Out:
#                   count
# Mortality Y / N
# NO               469566
# YES               10122

# %%
sns.countplot(df, x=df['SRC_REGISTRATION'])
plt.xticks(rotation=90)
plt.show()

# %%
src_count = df.groupby('SRC_REGISTRATION').agg(count=('SRC_REGISTRATION', 'size'))     
print(src_count)
# Out:
#                    count
# SRC_REGISTRATION
# CMO                14706
# D                 437948
# MC                  7934
# P                  19100

# %% [markdown]
# # 2. piechart

# %%
df['SEX'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='SEX'>

# %%
df['CASTE_NAME'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='CASTE_NAME'>

# %%
df['CATEGORY_NAME'].value_counts().head(5).plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='CATEGORY_NAME'>

# %%
df['MANDAL_NAME'].value_counts().head(5).plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='MANDAL_NAME'>

# %%
df['DISTRICT_NAME'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='DISTRICT_NAME'>

# %%
df['HOSP_TYPE'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='HOSP_TYPE'>

# %%
df['Mortality Y / N'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='Mortality Y / N'>

# %%
df['SRC_REGISTRATION'].value_counts().plot(kind='pie', autopct= "%0.1f")
# Out:
# <Axes: ylabel='SRC_REGISTRATION'>

# %%
df['SRC_REGISTRATION'].unique()
# Out:
# array(['D', 'P', 'MC', 'CMO'], dtype=object)

# %%
df['CASTE_NAME'].unique()
# Out:
# array(['BC', 'OC', 'SC', 'Minorities', 'ST', 'Others'], dtype=object)

# %%
df['CATEGORY_CODE'].unique()
# Out:
# array(['M6', 'S7', 'M5', 'S16', 'S5', 'S12', 'M4', 'S4', 'S13', 'S9',
#        'M7', 'S15', 'S10', 'M10', 'S1', 'M12', 'S14', 'S3', 'M8', 'M2',
#        'M1', 'S2', 'M11', 'S11', 'S8', 'S6', 'M9', 'S17', 'M3'],
#       dtype=object)

# %%
df['CATEGORY_NAME'].unique()
# Out:
# array(['NEPHROLOGY', 'CARDIAC AND CARDIOTHORACIC SURGERY', 'CARDIOLOGY',
#        'COCHLEAR IMPLANT SURGERY', 'ORTHOPEDIC  SURGERY AND PROCEDURES',
#        'MEDICAL ONCOLOGY', 'PEDIATRICS',
#        'GYNAECOLOGY AND OBSTETRICS  SURGERY', 'RADIATION ONCOLOGY',
#        'GENITO URINARY SURGERIES', 'NEUROLOGY', 'POLY TRAUMA',
#        'NEUROSURGERY', 'RHEUMATOLOGY', 'GENERAL SURGERY',
#        'GASTROENTEROLOGY', 'PLASTIC SURGERY', 'OPHTHALMOLOGY  SURGERY',
#        'PULMONOLOGY', 'GENERAL MEDICINE', 'CRITICAL CARE', 'ENT  SURGERY',
#        'ENDOCRINOLOGY', 'SURGICAL ONCOLOGY', 'PEDIATRIC SURGERIES',
#        'SURGICAL GASTRO ENTEROLOGY', 'DERMATOLOGY', 'PROSTHESES',
#        'INFECTIOUS DISEASES'], dtype=object)

# %%
df['VILLAGE'].unique()
# Out:
# array(['Lolugu', 'Borivanka', 'Kapasakuddi', ...,
#        'G.Palavalasa@T.V.P.Vala', 'Boithala', 'Koturupalle'], dtype=object)

# %%
df['DISTRICT_NAME'].unique()
# Out:
# array(['Srikakulam', 'Kurnool', 'Vizianagaram', 'Guntur',
#        'Vishakhapatnam', 'West Godavari', 'Krishna', 'East Godavari',
#        'Prakasam', 'Nellore', 'YSR Kadapa', 'Chittoor', 'Anantapur'],
#       dtype=object)

# %%
df['HOSP_DISTRICT'].unique()
# Out:
# array(['Srikakulam', 'Kurnool', 'Vishakhapatnam', 'Guntur', 'Hyderabad',
#        'Ranga Reddy', 'Prakasam', 'East Godavari', 'Nellore', 'Krishna',
#        'YSR Kadapa', 'Chittoor', 'Vizianagaram', 'Anantapur',
#        'West Godavari', 'Khammam', 'Warangal', 'Karimnagar', 'Nizamabad',
#        'Mahabubnagar'], dtype=object)

# %%
df['SEX'].unique()
# Out:
# array(['Female', 'Male', 'Male(Child)', 'Female(Child)'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479688 entries, 0 to 479687
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sno               479688 non-null  int64
#  1   AGE               479688 non-null  int64
#  2   SEX               479688 non-null  object
#  3   CASTE_NAME        479688 non-null  object
#  4   CATEGORY_CODE     479688 non-null  object
#  5   CATEGORY_NAME     479688 non-null  object
#  6   SURGERY_CODE      479688 non-null  object
#  7   SURGERY           479688 non-null  object
#  8   VILLAGE           479688 non-null  object
#  9   MANDAL_NAME       479688 non-null  object
#  10  DISTRICT_NAME     479688 non-null  object
#  11  PREAUTH_DATE      479688 non-null  datetime64[ns]
#  12  PREAUTH_AMT       479688 non-null  int64
#  13  CLAIM_DATE        479688 non-null  datetime64[ns]
#  14  CLAIM_AMOUNT      479688 non-null  int64
# ...
